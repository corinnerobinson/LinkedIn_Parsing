# %%
from bs4 import BeautifulSoup as BS
import requests

# %%
url = 'https://www.linkedin.com/pulse/solids-vs-liquids-could-history-separation-hinder-future-perettie/'

# %%
text = """<ul id="ember4817" class="feed-shared-likers-modal__actor-list actor-list ember-view">  <li class="actor-item">
<a data-control-name="like_actor" href="/in/dominic-j-elliston-6bb72b/" id="ember4818" class="ember-view">      <div class="actor-image">
        <div id="ember4819" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQGlbxHntfulGg/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=BTm5qsUJSjmLs9yLOFdUDlEQO1bN0cfmTCj-TFChcD0" class="avatar member EntityPhoto-circle-3" alt="Dominic J. Elliston">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Dominic J. Elliston
            <span id="ember4820" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">2nd degree connection</span>

<span class="dist-value">2nd</span>
</span>
                  </h3>
        <p class="headline">Managing Director at Galliard Healthcare Communications</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/solange-bishop-35b8b255/" id="ember4821" class="ember-view">      <div class="actor-image">
        <div id="ember4822" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Solange Bishop">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Solange Bishop
            <span id="ember4823" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Clinical Data Analyst at Sarah Cannon Research Institute</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/anna-kotzeva-113301/" id="ember4824" class="ember-view">      <div class="actor-image">
        <div id="ember4825" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQGQfKvjA7MCAA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=XsCxCra2RcyeItTh4zVByL0yy-Zy8B_JDtxl2dlpq4o" class="avatar member EntityPhoto-circle-3" alt="Anna Kotzeva">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Anna Kotzeva
            <span id="ember4826" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Global Pricing &amp; Market Access, Health Technology Assessment at Roche</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/andreas-beringer-512713124/" id="ember4827" class="ember-view">      <div class="actor-image">
        <div id="ember4828" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQExk1ORt5pkNA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=CrKp_oH-8qXNMBK1vLA5phStQW2rwzDuxvzNSztOmRI" class="avatar member EntityPhoto-circle-3" alt="Andreas Beringer">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Andreas Beringer
            <span id="ember4829" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">International Medical Director Personalised Healthcare Hoffmann-La Roche AG</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/sreekanthramachandran/" id="ember4830" class="ember-view">      <div class="actor-image">
        <div id="ember4831" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQH8psmWSmx5IA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=C1qgPBYkYPDz5bIQUYyooaSgeabwZmPr57zqsfmmpzg" class="avatar member EntityPhoto-circle-3" alt="Sreekanth Ramachandran">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Sreekanth Ramachandran
            <span id="ember4832" style="display: none;" class="feed-shared-actor-list__distance-badge distance-badge ember-view">  <span class="visually-hidden">&nbsp;</span>

<span class="dist-value">&nbsp;</span>
</span>
                  </h3>
        <p class="headline">Associate Director at Integral BioSciences Pvt. Ltd.</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/varunpaul6sigmaleader/" id="ember4833" class="ember-view">      <div class="actor-image">
        <div id="ember4834" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQE7wVhCGa3wEw/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=oay5YngME5AZPZCr36bPyRJBBay8gqdkqQHtl1xKRA4" class="avatar member EntityPhoto-circle-3" alt="Varun Paul">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Varun Paul
            <span id="ember4835" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Crafting strategy, implementing it, leading people, processes &amp; systems; driving results. Six Sigma Master Blackbelt</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/valentina-nicolini-486364158/" id="ember4836" class="ember-view">      <div class="actor-image">
        <div id="ember4837" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQHfUxXIg0JLXQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=zK__uIEV-kyIPKvlNvZb6NU_8KnRWIHjq8NdAL1h81w" class="avatar member EntityPhoto-circle-3" alt="Valentina Nicolini">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Valentina Nicolini
            <span id="ember4838" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">R&amp;D Lead Scientist; IBSA CH</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/kristina-best-james-483981/" id="ember4839" class="ember-view">      <div class="actor-image">
        <div id="ember4840" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQGxiPSTv6AJIQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=XoIe-VaIuc2ZecQGgHV9E-4i_pTVeJM0VoctQjIN5hc" class="avatar member EntityPhoto-circle-3" alt="Kristina Best James">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Kristina Best James
            <span id="ember4841" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Healthcare | Strategy | Innovation | Business Development | Marketing</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/victoryjoseph/" id="ember4842" class="ember-view">      <div class="actor-image">
        <div id="ember4843" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQE7SLDkOBVvEw/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=GWCWgutOJYU-u1Vh0Iy1ue4AubZtZ87sP3vV1BSklrs" class="avatar member EntityPhoto-circle-3" alt="Victory Joseph, PhD">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Victory Joseph, PhD
            <span id="ember4844" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Senior Scientific Researcher at Genentech</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/ilda-theka-28687230/" id="ember4845" class="ember-view">      <div class="actor-image">
        <div id="ember4846" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQFiAo7esFqf7A/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=m3LZ2lY8V8BeaqU4UYshb2ZiLMuOEGnGGqLsksQh-nA" class="avatar member EntityPhoto-circle-3" alt="Ilda Theka">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Ilda Theka
            <span id="ember4847" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Biomedical Research Scientist, PhD</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/carolh1/" id="ember4848" class="ember-view">      <div class="actor-image">
        <div id="ember4849" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Carol Wood">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Carol Wood
            <span id="ember4850" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Head of Communications and Engagement (Wessex) at NHS England</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/stephanie-moeller-75a35a9a/" id="ember4851" class="ember-view">      <div class="actor-image">
        <div id="ember4852" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Stephanie Moeller">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Stephanie Moeller
            <span id="ember4853" style="display: none;" class="feed-shared-actor-list__distance-badge distance-badge ember-view">  <span class="visually-hidden">&nbsp;</span>

<span class="dist-value">&nbsp;</span>
</span>
                  </h3>
        <p class="headline">Clinical Research Specialist, Consumer Health Care Division, 3M</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/natashahansjee/" id="ember4854" class="ember-view">      <div class="actor-image">
        <div id="ember4855" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Natasha Hansjee">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Natasha Hansjee
            <span id="ember4856" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Global Commercial Team Leader and Women in Leadership co-chair with a passion for science and people</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/giovanni-tangherlini-98a1487b/" id="ember4857" class="ember-view">      <div class="actor-image">
        <div id="ember4858" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQHDXAc-QZIcgA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=YZdoZ8LKTN1Gw4HfuF3u-qcRaQnFEC2whXjgSoF6UEw" class="avatar member EntityPhoto-circle-3" alt="Giovanni Tangherlini">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Giovanni Tangherlini
            <span id="ember4859" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">PhD at Cim-IMPRS, University of Münster, Germany.</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/oliverbalcells/" id="ember4860" class="ember-view">      <div class="actor-image">
        <div id="ember4861" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQGMmBaRfdG9LA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=8VblRdT-ud3BzgTL64BbbcxSQlbGLnXB238jHbDeVY0" class="avatar member EntityPhoto-circle-3" alt="Oliver Balcells Navarro">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Oliver Balcells Navarro
            <span id="ember4862" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">CEO &amp; Co Founder en RheoDx</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/dr-katiba-hacene-ouhib-53345a10/" id="ember4863" class="ember-view">      <div class="actor-image">
        <div id="ember4864" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQH0ycz8C-d2_Q/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=ypA9d-HqBtjoXsxzQ5sEqQkmzwTboZ-OoDxU3lkgXn8" class="avatar member EntityPhoto-circle-3" alt="Dr Katiba HACENE-OUHIB">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Dr Katiba HACENE-OUHIB
            <span id="ember4865" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Médecin connectée. Formations-rédactions. Expertise clinique et en industrie pharma en onco-hématologie de+ de 20 ans.</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/katrine-thor-andersen-mba/" id="ember4866" class="ember-view">      <div class="actor-image">
        <div id="ember4867" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQHe0Kdaoh75TQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=Y8bVGIk_qx9InDcILGFUwJ7bthFre-zZOllLP-GoyFw" class="avatar member EntityPhoto-circle-3" alt="Katrine Thor Andersen">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Katrine Thor Andersen
            <span id="ember4868" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Deputy Director | Bill &amp; Melinda Gates Foundation | Silo Buster | Alliance Management | Operational Exellence</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/clive-jabangwe-b3208439/" id="ember4869" class="ember-view">      <div class="actor-image">
        <div id="ember4870" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQGHbV6-Ym16GQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=aeO3SwFvKK1yaAusPP3fzYbaBxJq-KlZtUtavMiTvOY" class="avatar member EntityPhoto-circle-3" alt="Clive Jabangwe">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Clive Jabangwe
            <span id="ember4871" style="display: none;" class="feed-shared-actor-list__distance-badge distance-badge ember-view">  <span class="visually-hidden">&nbsp;</span>

<span class="dist-value">&nbsp;</span>
</span>
                  </h3>
        <p class="headline">MSc Medical Biotechnology (UPO)</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/andreea-steriu-1296b81a/" id="ember4872" class="ember-view">      <div class="actor-image">
        <div id="ember4873" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQEv25mlYvEEcQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=yFcCxgrZow_7UfI7TJJU9CO24ddiw2GAm_jvGPn9nVY" class="avatar member EntityPhoto-circle-3" alt="Andreea Steriu">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Andreea Steriu
            <span id="ember4874" style="display: none;" class="feed-shared-actor-list__distance-badge distance-badge ember-view">  <span class="visually-hidden">&nbsp;</span>

<span class="dist-value">&nbsp;</span>
</span>
                  </h3>
        <p class="headline">University Lecturer at UMF Carol Davila</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/mihaela-ianosev-107513/" id="ember4875" class="ember-view">      <div class="actor-image">
        <div id="ember4876" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQEUA1bIADv4Yw/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=_WJyhRWf-LVR-c0F6DkDqZTv4PaOLEThQ-yf2S-JwDw" class="avatar member EntityPhoto-circle-3" alt="Mihaela Ianosev">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Mihaela Ianosev
            <span id="ember4877" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">European Medical Director Specialty Care Unit</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/timothy-meyer-9a469a27/" id="ember4878" class="ember-view">      <div class="actor-image">
        <div id="ember4879" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQFxLpdw--k8Cw/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=3JMjw-pGJlRgfCXn_spIX66__lswgLl6CEzLDd5mN2g" class="avatar member EntityPhoto-circle-3" alt="Timothy Meyer">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Timothy Meyer
            <span id="ember4880" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Quality</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/taslim-uddin-5a954488/" id="ember4881" class="ember-view">      <div class="actor-image">
        <div id="ember4882" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQH11caavcfwLA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=bRty2a6uegsROjnyU6YGpnse0t4P_VUynBLD6BYCZWM" class="avatar member EntityPhoto-circle-3" alt="Taslim Uddin">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Taslim Uddin
            <span id="ember4883" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Managing Director at Clipping Path Associate</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/enriquecastano/" id="ember4884" class="ember-view">      <div class="actor-image">
        <div id="ember4885" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQHkfnlyF3BINA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=aY0-mtR6v8RNtJYx1fS11WGoIgOiUkcTjzPabWFUSz4" class="avatar member EntityPhoto-circle-3" alt="Enrique Castaño">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Enrique Castaño
            <span id="ember4886" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Sales &amp; Business Development Director at Fitoplancton Marino</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/erin-p-1893496/" id="ember4887" class="ember-view">      <div class="actor-image">
        <div id="ember4888" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQEgSjPTvQAarA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=av42pVDsbrEItAtKaSKVzA1LgPvOfY-m4nJvboqz0ps" class="avatar member EntityPhoto-circle-3" alt="Erin P.">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Erin P.
            <span id="ember4889" style="display: none;" class="feed-shared-actor-list__distance-badge distance-badge ember-view">  <span class="visually-hidden">&nbsp;</span>

<span class="dist-value">&nbsp;</span>
</span>
                  </h3>
        <p class="headline">Senior Oncology Specialist at Novartis</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/seanmcgrath99/" id="ember4890" class="ember-view">      <div class="actor-image">
        <div id="ember4891" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQGaw7OQp3Je4A/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=GZB8i85l9-CBUxaxvEgSgcGcqFDOucN7nrPy4JlG4Tg" class="avatar member EntityPhoto-circle-3" alt="Sean McGrath">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Sean McGrath
            <span id="ember4892" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Entrepreneur, advisor, mentor, investor, consultant, NED in healthcare, oncology, sports, start-ups, voluntary sectors</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/paola-franco-a579705/" id="ember4893" class="ember-view">      <div class="actor-image">
        <div id="ember4894" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Paola Franco">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Paola Franco
            <span id="ember4895" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Authentic, Influential and Innovative Leader</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/jo-armstrong-52023980/" id="ember4896" class="ember-view">      <div class="actor-image">
        <div id="ember4897" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQGK44VYaxcicQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=100MlF3jQrdxZ9CaE7Mg2SnQwvt7B6xsCwgH5HTEMbE" class="avatar member EntityPhoto-circle-3" alt="Jo Armstrong">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Jo Armstrong
            <span id="ember4898" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Country Clinical Operations Leader (Oncology) at Roche.</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/castrec-emmanuelle-0460622/" id="ember4899" class="ember-view">      <div class="actor-image">
        <div id="ember4900" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQETi9ifK_dlsw/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=-NQPJCofIfccssR6OYRfK_eFre779DOBgyBRM55hJBY" class="avatar member EntityPhoto-circle-3" alt="Castrec Emmanuelle">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Castrec Emmanuelle
            <span id="ember4901" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Oncology Sales representative (lung Cancer) at Roche Pharmaceuticals</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/ulrike-jahnke-17249211/" id="ember4902" class="ember-view">      <div class="actor-image">
        <div id="ember4903" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQGo5XFM5JIVDQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=aZ7jzDljnludwwB7ltBkUsvgz-76iIjTJZRaEL93PK4" class="avatar member EntityPhoto-circle-3" alt="Ulrike Jahnke">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Ulrike Jahnke
            <span id="ember4904" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Senior Editor (Forecast Team) at Clarivate Analytics</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/shane-bell-mba-9471085/" id="ember4905" class="ember-view">      <div class="actor-image">
        <div id="ember4906" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Shane Bell, MBA">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Shane Bell, MBA
            <span id="ember4907" style="display: none;" class="feed-shared-actor-list__distance-badge distance-badge ember-view">  <span class="visually-hidden">&nbsp;</span>

<span class="dist-value">&nbsp;</span>
</span>
                  </h3>
        <p class="headline">Senior Oncology Account Manager</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/dr-rajalakshmi-nair-6691131b/" id="ember4908" class="ember-view">      <div class="actor-image">
        <div id="ember4909" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Dr. Rajalakshmi Nair">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Dr. Rajalakshmi Nair
            <span id="ember4910" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Engagement Manager, Oncology and Thought Leadership</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/ajainiqvia/" id="ember4911" class="ember-view">      <div class="actor-image">
        <div id="ember4912" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5103AQHdU7jyr_y0hQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=ihAnNZXT8P5anZntzfDL101pEDKXzlrH-yfpl4mickw" class="avatar member EntityPhoto-circle-3" alt="Abhishek Jain">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Abhishek Jain
            <span id="ember4913" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Execution - Get Things Done | Strategic Account/Stakeholder Mgmt | Knowledge/Bid Mgmt | Large Engagement PMO | Analytics</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/psimms/" id="ember4914" class="ember-view">      <div class="actor-image">
        <div id="ember4915" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5103AQEjUsXSNe1HMQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=JxUx0bPTC1w2E98TGR3AmxVQfULeY2Qdz3ZgXNZuIgU" class="avatar member EntityPhoto-circle-3" alt="Paul Simms">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Paul Simms
            <span id="ember4916" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Chairman, eyeforpharma</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/amy-black/" id="ember4917" class="ember-view">      <div class="actor-image">
        <div id="ember4918" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQESVcw6a9nW-Q/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=Tent1_4nymKHyJ8tHSSOnBlmzui0JpN5dbxgiyAMYcQ" class="avatar member EntityPhoto-circle-3" alt="Amy Black">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Amy Black
            <span id="ember4919" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Awesome Workshops | Project and Process Management</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/lisaportelli/" id="ember4920" class="ember-view">      <div class="actor-image">
        <div id="ember4921" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Lisa Portelli, PMP®">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Lisa Portelli, PMP®
            <span id="ember4922" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Organizational Leader - Biotech, Engineering, IT, Supply Chain focused</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/armenboldi/" id="ember4923" class="ember-view">      <div class="actor-image">
        <div id="ember4924" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Armen Boldi">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Armen Boldi
            <span id="ember4925" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Senior Global Project Manager, Portfolio and Product Development Strategy at Genentech</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/christophercotterphd/" id="ember4926" class="ember-view">      <div class="actor-image">
        <div id="ember4927" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQHcd1Pq6vX_CA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=QImfWlWgMW5U_Pig4qE-PVrMOf-DNfcc0VvhFdYeShI" class="avatar member EntityPhoto-circle-3" alt="Christopher Cotter, Ph.D.">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Christopher Cotter, Ph.D.
            <span id="ember4928" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Senior Clinical Project Manager at Genentech/Roche</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/aphernandez/" id="ember4929" class="ember-view">      <div class="actor-image">
        <div id="ember4930" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQFzuSCi0UJnWA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=ean0IB0djUpCwY9CzTuostEvY4mynlO0NEolTzCOKMQ" class="avatar member EntityPhoto-circle-3" alt="Paola Hernández, Ph.D.">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Paola Hernández, Ph.D.
            <span id="ember4931" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Applied life sciences professional with experience in genomics, business strategy, and project management.</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/fatima-ina-51830017/" id="ember4932" class="ember-view">      <div class="actor-image">
        <div id="ember4933" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQEp9jPFrAidww/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=SnZ2_AzwaPj9Znt5HiTZeXOHaJJUNUX_SoF5qQ8rGIg" class="avatar member EntityPhoto-circle-3" alt="Fatima Ina">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Fatima Ina
            <span id="ember4934" style="display: none;" class="feed-shared-actor-list__distance-badge distance-badge ember-view">  <span class="visually-hidden">&nbsp;</span>

<span class="dist-value">&nbsp;</span>
</span>
                  </h3>
        <p class="headline">Farmaceutica Adjunta at oficina de farmacia</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/dajuan-stallworth-1942b595/" id="ember4935" class="ember-view">      <div class="actor-image">
        <div id="ember4936" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Dajuan Stallworth">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Dajuan Stallworth
            <span id="ember4937" style="display: none;" class="feed-shared-actor-list__distance-badge distance-badge ember-view">  <span class="visually-hidden">&nbsp;</span>

<span class="dist-value">&nbsp;</span>
</span>
                  </h3>
        <p class="headline">Sales Specialist at McKesson Life Sciences</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/dominiquecharvetmartin/" id="ember4938" class="ember-view">      <div class="actor-image">
        <div id="ember4939" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQEAdqUunVxsng/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=x17yUR1tpv_xgptIR8_faqV_68i41UZiICtCfPo3-a8" class="avatar member EntityPhoto-circle-3" alt="Dominique Martin">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Dominique Martin
            <span id="ember4940" style="display: none;" class="feed-shared-actor-list__distance-badge distance-badge ember-view">  <span class="visually-hidden">&nbsp;</span>

<span class="dist-value">&nbsp;</span>
</span>
                  </h3>
        <p class="headline">Sales Director Northern Europe</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/martin-paine-phd-1a899466/" id="ember4941" class="ember-view">      <div class="actor-image">
        <div id="ember4942" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQG92Zd8INHqMg/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=Qyf-25tuUNN37P9xbrYFjBDeWtgJ63OvujvZASbGHS8" class="avatar member EntityPhoto-circle-3" alt="Martin Paine, PhD">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Martin Paine, PhD
            <span id="ember4943" style="display: none;" class="feed-shared-actor-list__distance-badge distance-badge ember-view">  <span class="visually-hidden">&nbsp;</span>

<span class="dist-value">&nbsp;</span>
</span>
                  </h3>
        <p class="headline">Business Developer, Europe at ImaBiotech</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/lana-andrianova-md-49328725/" id="ember4944" class="ember-view">      <div class="actor-image">
        <div id="ember4945" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQGXJZvoLCy-mQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=gsqlWgwlOzxbXlcvqUAJsJj4JXQ7B8ve3FagE5M4Dsw" class="avatar member EntityPhoto-circle-3" alt="Lana Andrianova, MD">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Lana Andrianova, MD
            <span id="ember4946" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Clinical Operations Lead at Syneos Health (Previously INC Research/inVentiv Health)</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/filippo-federico-fidone-28a16b16a/" id="ember4947" class="ember-view">      <div class="actor-image">
        <div id="ember4948" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Filippo Federico Fidone">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Filippo Federico Fidone
            <span id="ember4949" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Medical Advisor Oncology (MBC, NHL, BTcP)</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/ashutosh-pandey-7b96132/" id="ember4950" class="ember-view">      <div class="actor-image">
        <div id="ember4951" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQHMo5oCcKcmXQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=COzWSnQ0b_fjCpFtVog10Tkivgnf3CjzN2oCeUZWWWs" class="avatar member EntityPhoto-circle-3" alt="Ashutosh Pandey">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Ashutosh Pandey
            <span id="ember4952" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Director IT and Strategic Sourcing</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/frederick-weston-0b78a138/" id="ember4953" class="ember-view">      <div class="actor-image">
        <div id="ember4954" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Frederick Weston">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Frederick Weston
            <span id="ember4955" style="display: none;" class="feed-shared-actor-list__distance-badge distance-badge ember-view">  <span class="visually-hidden">&nbsp;</span>

<span class="dist-value">&nbsp;</span>
</span>
                  </h3>
        <p class="headline">President &amp; CEO at Addiction Management Systems (AMS)</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/bahillier/" id="ember4956" class="ember-view">      <div class="actor-image">
        <div id="ember4957" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQFtgNW-HI9cug/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=ZX1Ouqq_CJoQSdX4buC-S7XVmeRP5zEalCI-9Vk0MpI" class="avatar member EntityPhoto-circle-3" alt="Barry Hillier">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Barry Hillier
            <span id="ember4958" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Think + Create + Inspire + Connect</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/arthur-marshall-tielung/" id="ember4959" class="ember-view">      <div class="actor-image">
        <div id="ember4960" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Arthur Marshall Tielung">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Arthur Marshall Tielung
            <span id="ember4961" style="display: none;" class="feed-shared-actor-list__distance-badge distance-badge ember-view">  <span class="visually-hidden">&nbsp;</span>

<span class="dist-value">&nbsp;</span>
</span>
                  </h3>
        <p class="headline">Regulatory Officer at Novartis Indonesia</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/seanfrobertson/" id="ember4962" class="ember-view">      <div class="actor-image">
        <div id="ember4963" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQGfJOjFGwIFAA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=qH_NjQUuP1TBRvBp3rnajveO9_6vEtm2Id7Hy4OFxqA" class="avatar member EntityPhoto-circle-3" alt="Sean Robertson">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Sean Robertson
            <span id="ember4964" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Strategic Alignment and Major Problems Solved In 2 Days. Tactics, Execution for Fortune 500 Global Pharma</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/dr-samira-curdt-b266538/" id="ember4965" class="ember-view">      <div class="actor-image">
        <div id="ember4966" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQE7AsaY-yW1Qg/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=yKWN9zD7SfsUhYl-YGn2Z7duvxyyjtrUEL1hSbekzpM" class="avatar member EntityPhoto-circle-3" alt="Dr Samira Curdt">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Dr Samira Curdt
            <span id="ember4967" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Translational Medicine Scientist at Roche Pharma Research and Early Development</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/yossi-mograbi-a21a302/" id="ember4968" class="ember-view">      <div class="actor-image">
        <div id="ember4969" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQEUsNDwIlWCIQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=Ls0GKA1WOFqVoaFEebholYq_Cvk0UrrP6TnWnVvgMXM" class="avatar member EntityPhoto-circle-3" alt="Yossi Mograbi">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Yossi Mograbi
            <span id="ember4970" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Founder / CEO at OneDay - Biotech and Pharma Ltd.</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/silvana-dangiolo-a275317b/" id="ember4971" class="ember-view">      <div class="actor-image">
        <div id="ember4972" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQGfyVU1Dyqjfw/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=M1vWWr09R589Gj0mt10g-RhMlTglcOPAwYNV1WKbqEA" class="avatar member EntityPhoto-circle-3" alt="Silvana DANGIOLO">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Silvana DANGIOLO
            <span id="ember4973" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Medical Geneticist and Pediatrician</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/susanne-zeitler-0b394778/" id="ember4974" class="ember-view">      <div class="actor-image">
        <div id="ember4975" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQEds3KN5eWPLA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=JPdj0jT6Jerh3ET6iS9g9-BWnqNkIf7G_F-jUtj42HE" class="avatar member EntityPhoto-circle-3" alt="Susanne Zeitler">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Susanne Zeitler
            <span id="ember4976" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Business Lead North Oncology bei Servier</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/huray-kasikci-ayhan-1718a4/" id="ember4977" class="ember-view">      <div class="actor-image">
        <div id="ember4978" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Huray Kasikci Ayhan">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Huray Kasikci Ayhan
            <span id="ember4979" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Snr Global Project Manager and International Operations Team Lead, Roche Foundation Medicine</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/pascale-cl%C3%A9ment-20443b59/" id="ember4980" class="ember-view">      <div class="actor-image">
        <div id="ember4981" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5103AQFHOLxL6hWsDg/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=rU8-5nKj07Sbil0kfxDbWDQKED7NFJk7zkN-GIO0RUE" class="avatar member EntityPhoto-circle-3" alt="Pascale Clément">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Pascale Clément
            <span id="ember4982" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">National Key Account Manager</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/robert-jackson-732058156/" id="ember4983" class="ember-view">      <div class="actor-image">
        <div id="ember4984" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Robert Jackson">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Robert Jackson
            <span id="ember4985" style="display: none;" class="feed-shared-actor-list__distance-badge distance-badge ember-view">  <span class="visually-hidden">&nbsp;</span>

<span class="dist-value">&nbsp;</span>
</span>
                  </h3>
        <p class="headline">--</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/maurobrovelli/" id="ember4986" class="ember-view">      <div class="actor-image">
        <div id="ember4987" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQE3fdEt49i3mg/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=jV3X57OVoFFK2WbsNPfS1R5zOoGwMTy6VmmxVYpOhtE" class="avatar member EntityPhoto-circle-3" alt="Mauro Brovelli">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Mauro Brovelli
            <span id="ember4988" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Foundation Medicine Customer Service at Roche</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/thadchawadee-wejrungsikul-3307b874/" id="ember4989" class="ember-view">      <div class="actor-image">
        <div id="ember4990" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQFnTMVSq9RYSQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=ur8NVdJYrD6aUzFU1H4sB9LQJ5VXUQcTnujKOw2YcY0" class="avatar member EntityPhoto-circle-3" alt="Thadchawadee Wejrungsikul">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Thadchawadee Wejrungsikul
            <span id="ember4991" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Market Access Manager at MSD</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/susanjulianbudd/" id="ember4992" class="ember-view">      <div class="actor-image">
        <div id="ember4993" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Susan Julian Budd">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Susan Julian Budd
            <span id="ember4994" style="display: none;" class="feed-shared-actor-list__distance-badge distance-badge ember-view">  <span class="visually-hidden">&nbsp;</span>

<span class="dist-value">&nbsp;</span>
</span>
                  </h3>
        <p class="headline">Specialty Medical Sales Professional with ability to build relationships and motivate customers</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/alan-levoguer-2024986/" id="ember4995" class="ember-view">      <div class="actor-image">
        <div id="ember4996" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQE31tdzkrmnAQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=cH25PIhV-ttKdojT4qMK5w3PC8SqWcwijrQrt2a6lWg" class="avatar member EntityPhoto-circle-3" alt="Alan LeVoguer">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Alan LeVoguer
            <span id="ember4997" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Commercial Innovation Leader, Region Europe at Roche</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/jacqueline-karmel-58aa855/" id="ember4998" class="ember-view">      <div class="actor-image">
        <div id="ember4999" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQHWs1Rpr0tP-g/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=4r5Q1cxgqsV1GUkZSivd4k3tMkMCB1tbFqdBn4nqcNU" class="avatar member EntityPhoto-circle-3" alt="Jacqueline Karmel">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Jacqueline Karmel
            <span id="ember5000" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Principal International Scientific Director, Global Medical Team Lead, Cancer Immunotherapy, Roche Products Ltd.</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/sajokaduthanam/" id="ember5001" class="ember-view">      <div class="actor-image">
        <div id="ember5002" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Sajo Kaduthanam">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Sajo Kaduthanam
            <span id="ember5003" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Scientific Field Support bei Molecular Health GmbH</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/joachim-keller-87972b7/" id="ember5004" class="ember-view">      <div class="actor-image">
        <div id="ember5005" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQEUnMxnz1n6wA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=rqWf6IuPt8rWw5R8_jPC_7t1NOjOPfTqlqW-979_9gc" class="avatar member EntityPhoto-circle-3" alt="Joachim Keller">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Joachim Keller
            <span id="ember5006" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Partner at ZS Associates</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/roger-joachim-grau-82b63733/" id="ember5007" class="ember-view">      <div class="actor-image">
        <div id="ember5008" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQHwk4ThD4-9HQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=SVw-huDSYOIHp18fERTbpxEM-I-aSs3wn1t062H1E-g" class="avatar member EntityPhoto-circle-3" alt="Roger Joachim Grau">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Roger Joachim Grau
            <span id="ember5009" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">NBE/Biosimilar CMC Expert bei Solvias</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/lenka-kellermann-88009b5/" id="ember5010" class="ember-view">      <div class="actor-image">
        <div id="ember5011" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQFbj510tJiRGQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=wA3E5tJ3tkfZPlFkeVfBXfY0ljodIxFdNClymM9R7dU" class="avatar member EntityPhoto-circle-3" alt="Lenka Kellermann">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Lenka Kellermann
            <span id="ember5012" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Owner, OncologyInformationService O.I.s)</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/hang-le-7200462b/" id="ember5013" class="ember-view">      <div class="actor-image">
        <div id="ember5014" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5103AQG-xtvviLgMPg/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=f0sHF8QsuHZUcGXX8hLmibkp6EsoJJGt5kHyU1w4-tk" class="avatar member EntityPhoto-circle-3" alt="Hang Le">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Hang Le
            <span id="ember5015" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">APAC Regional Market Access Lead at Roche</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/kathrin-tissot-0ba33124/" id="ember5016" class="ember-view">      <div class="actor-image">
        <div id="ember5017" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQEKUJIIzOaRfA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=BIJ1QA0FnNvNWTUJQtgpcOuYkFIsBzQbJLM3ku8GbME" class="avatar member EntityPhoto-circle-3" alt="Kathrin Tissot">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Kathrin Tissot
            <span id="ember5018" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Business Team Head at MorphoSys AG</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/mason-shih-03a408/" id="ember5019" class="ember-view">      <div class="actor-image">
        <div id="ember5020" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQHHjqEhzBE2Hw/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=xxbCndYTu9J8rEw-zvoXVZvrPIjocrp3NZdatdvifTo" class="avatar member EntityPhoto-circle-3" alt="Mason Shih">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Mason Shih
            <span id="ember5021" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Global Head, Core Safety Science, Safety Risk Management at Roche</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/dimitris-karyotis-3b31a02b/" id="ember5022" class="ember-view">      <div class="actor-image">
        <div id="ember5023" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQH5nUxSZ2oyHg/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=Fj4VBud9RwzCTAU_PLDQffGNrdLHkre5xqRDkQFDjS4" class="avatar member EntityPhoto-circle-3" alt="Dimitris Karyotis">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Dimitris Karyotis
            <span id="ember5024" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">International Product Manager at Roche</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/dr-wolfram-schmidt-3617b511/" id="ember5025" class="ember-view">      <div class="actor-image">
        <div id="ember5026" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQEQ8DZd8UxfoQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=FIMti9ichXQxh3HJDXDuNucUludmr0dL8_sT_yO9roI" class="avatar member EntityPhoto-circle-3" alt="Dr. Wolfram Schmidt">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Dr. Wolfram Schmidt
            <span id="ember5027" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">General Manager Roche Pharma</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/lyndsay-oglesby-a233538/" id="ember5028" class="ember-view">      <div class="actor-image">
        <div id="ember5029" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Lyndsay Oglesby">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Lyndsay Oglesby
            <span id="ember5030" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Oncology Market Analysis &amp; Strategy</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/carlos-martin-9612b2/" id="ember5031" class="ember-view">      <div class="actor-image">
        <div id="ember5032" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQFcE162-7ecDw/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=Vtpb60zS76wi0mUpZtPr6idZSCGRl6HLdth-4zHtGMI" class="avatar member EntityPhoto-circle-3" alt="Carlos Martin">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Carlos Martin
            <span id="ember5033" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">USA Executive Business Director, Solid Tumors at Novartis Oncology at Novartis</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/ciro-caravaggio-a7a9879/" id="ember5034" class="ember-view">      <div class="actor-image">
        <div id="ember5035" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQGGXJjHQP4rEw/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=XXRfyBpstWYkW-auDdiCjGftiDaU8iVRon69YOJulxo" class="avatar member EntityPhoto-circle-3" alt="Ciro Caravaggio">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Ciro Caravaggio
            <span id="ember5036" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Sub-regional head APAC at Roche</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/kristen-leng/" id="ember5037" class="ember-view">      <div class="actor-image">
        <div id="ember5038" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5103AQFl7uzh-zh90Q/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=8x1jVaCOyW-ilmQ8mrAGSK5EF1pbLfanL4DKiajGfns" class="avatar member EntityPhoto-circle-3" alt="Kristen Leng">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Kristen Leng
            <span id="ember5039" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Business Development - PRA Health Sciences</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/louisemwood/" id="ember5040" class="ember-view">      <div class="actor-image">
        <div id="ember5041" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQG_GZCfGIC_Xw/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=I8tRB78dTf3983Ofa1mMaXHP3UY1VcTXJxgvP2Pfqps" class="avatar member EntityPhoto-circle-3" alt="Louise Wood">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Louise Wood
            <span id="ember5042" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Change Management Specialist at Agile Business Techniques Ltd</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/brianjpetteys/" id="ember5043" class="ember-view">      <div class="actor-image">
        <div id="ember5044" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Brian J. Petteys">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Brian J. Petteys
            <span id="ember5045" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Senior Product Manager, Avastin Marketing at Genentech</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/noelle-gaskill-mba-acrp-cp-9301a2a/" id="ember5046" class="ember-view">      <div class="actor-image">
        <div id="ember5047" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQGIUKNLbuQSwA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=f3cZfsiUqhQkR_bwsX5K3SFr3HRDMYgiG5XET9U6VqU" class="avatar member EntityPhoto-circle-3" alt="Noelle Gaskill, MBA, ACRP-CP">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Noelle Gaskill, MBA, ACRP-CP
            <span id="ember5048" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Vice President, Research Operations</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/clinscience/" id="ember5049" class="ember-view">      <div class="actor-image">
        <div id="ember5050" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Said Bouseida">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Said Bouseida
            <span id="ember5051" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Clinical Scientist - Oncology Immunotherapy CEA-TCB - F. Hoffmann - La Roche</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/andreasmerz/" id="ember5052" class="ember-view">      <div class="actor-image">
        <div id="ember5053" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5103AQEED_J0pBcNOw/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=53N2ao-BtKcjMRTm91ryBNYuEjCYB5s8wvEvDpMfypM" class="avatar member EntityPhoto-circle-3" alt="Andreas Merz, PhD">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Andreas Merz, PhD
            <span id="ember5054" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Global Commercial Assessment Lead - Oncology Business Development</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/mchabria/" id="ember5055" class="ember-view">      <div class="actor-image">
        <div id="ember5056" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Mamta Chabria, PhD">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Mamta Chabria, PhD
            <span id="ember5057" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Connecting Science to Products - Pharma, Diagnostics &amp; Medical Devices</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/joanne-steiner-3948723/" id="ember5058" class="ember-view">      <div class="actor-image">
        <div id="ember5059" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQFlojLQ57Evxg/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=CXYEP5h352HzjcitYVaGhAZ2q6sbuDO7Zw1j-3wW3GQ" class="avatar member EntityPhoto-circle-3" alt="Joanne Steiner">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Joanne Steiner
            <span id="ember5060" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Founding Partner, Apriori Consulting</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/virginia-gardner/" id="ember5061" class="ember-view">      <div class="actor-image">
        <div id="ember5062" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQGmqYEiVthJAw/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=F9MM-hAebVwXOcHugZLFRksUSU6qSaUygrxnWg5rgrM" class="avatar member EntityPhoto-circle-3" alt="Virginia Gardner">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Virginia Gardner
            <span id="ember5063" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Project Management, Functional/Data Analysis, Compliance &amp; Legal/Law/Regulation Implementation and Reporting</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/jambstew/" id="ember5064" class="ember-view">      <div class="actor-image">
        <div id="ember5065" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQGTzM_hnsY7qA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=zN3_pHdNrK3qWgopluYEdpyxsy9xFucnTlDk4l1QM4A" class="avatar member EntityPhoto-circle-3" alt="Ben Stewart">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Ben Stewart
            <span id="ember5066" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Foundation Medicine Business Development</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/archana-sah-ms-pharm-pmp-069831a/" id="ember5067" class="ember-view">      <div class="actor-image">
        <div id="ember5068" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQFg9JEDLfiCFA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=tt4cq70EzY5qTbJ5aZF4mp4mwAAzMFSEnclTwOEpQZY" class="avatar member EntityPhoto-circle-3" alt="Archana Sah, MS(Pharm.), PMP">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Archana Sah, MS(Pharm.), PMP
            <span id="ember5069" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Therapeutic Area Leader, Oncology, Director, Clinical Operations</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/gail-rivas-b5975648/" id="ember5070" class="ember-view">      <div class="actor-image">
        <div id="ember5071" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQFf8KU0mpoaYw/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=-qo2GwwUrPy4MBFphtXmtJ0g02LNme1FvzSs5Oup2Wg" class="avatar member EntityPhoto-circle-3" alt="Gail Rivas">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Gail Rivas
            <span id="ember5072" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Quality Assistant at Genentech</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/angie-namenuk-aab772b/" id="ember5073" class="ember-view">      <div class="actor-image">
        <div id="ember5074" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQF0eCi1wraKRQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=RZjj3gGAKxuvu29H_eqzPteWg8PtJIfZVkyxin6PfN4" class="avatar member EntityPhoto-circle-3" alt="Angie Namenuk">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Angie Namenuk
            <span id="ember5075" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Sr Director Business Management and Communications / Corporate Pharma/DIA Collaboration Manager at Genentech</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/doug-leng-46849835/" id="ember5076" class="ember-view">      <div class="actor-image">
        <div id="ember5077" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQGkXyxr_Dv-Qg/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=ylfH3h3lX2HSCCIU07qPIIy_4iOAk9IX_Bx38NRbZJc" class="avatar member EntityPhoto-circle-3" alt="Doug Leng">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Doug Leng
            <span id="ember5078" style="display: none;" class="feed-shared-actor-list__distance-badge distance-badge ember-view">  <span class="visually-hidden">&nbsp;</span>

<span class="dist-value">&nbsp;</span>
</span>
                  </h3>
        <p class="headline">Expert in solving corrosion control problems</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/gina-chapman-0467103/" id="ember5079" class="ember-view">      <div class="actor-image">
        <div id="ember5080" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Gina Chapman">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Gina Chapman
            <span id="ember5081" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Vice President, Head of Hemophilia, Genentech USA</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/rociolopezmarcos/" id="ember5082" class="ember-view">      <div class="actor-image">
        <div id="ember5083" class="feed-shared-avatar-image b0 member ember-view">  <img src="..." class="avatar member EntityPhoto-circle-3 ghost-person" alt="Rocío López Marcos">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Rocío López Marcos
            <span id="ember5084" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Therapeutic Specialty Sales Consultant Spain and Portugal en Terumo BCT</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/nancy-nelson-774b205/" id="ember5085" class="ember-view">      <div class="actor-image">
        <div id="ember5086" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQGk1jFvmGYuPQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=-5IUFhE3FUN-olukbVVwNkpkNBo8fNbNzRulLYAnRvo" class="avatar member EntityPhoto-circle-3" alt="Nancy Nelson">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Nancy Nelson
            <span id="ember5087" style="display: none;" class="feed-shared-actor-list__distance-badge distance-badge ember-view">  <span class="visually-hidden">&nbsp;</span>

<span class="dist-value">&nbsp;</span>
</span>
                  </h3>
        <p class="headline">Management Analyst II at City of Dublin, Public Works Department</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/jimena-tejada-61370b5a/" id="ember5088" class="ember-view">      <div class="actor-image">
        <div id="ember5089" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5103AQFFB_uLsGGoIg/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=ZXvq22gAmFNUEMfT3zHVcoTigCmX9XiNfFUoZKNlr68" class="avatar member EntityPhoto-circle-3" alt="Jimena Tejada">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Jimena Tejada
            <span id="ember5090" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Group Medical Manager en Roche</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/genoveva-vivancos-06b9121a/" id="ember5091" class="ember-view">      <div class="actor-image">
        <div id="ember5092" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQHNIfLpLe15VQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=RpyF6iAdxePV9ZeMZPplttP7GjRi4Or3K1EGKYeFeIc" class="avatar member EntityPhoto-circle-3" alt="Genoveva Vivancos">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Genoveva Vivancos
            <span id="ember5093" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Product Manager Oncology, Roche</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/kandeepan-ganeshalingam-66819b23/" id="ember5094" class="ember-view">      <div class="actor-image">
        <div id="ember5095" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQGKPdPUARjHgA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=K6glugN0UKbJHKQIAPKO8uMXO_ODBDWHSrMVuvG4tGI" class="avatar member EntityPhoto-circle-3" alt="Kandeepan Ganeshalingam">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Kandeepan Ganeshalingam
            <span id="ember5096" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Executive Director, Oncology Therapeutic Area Head, European Clinical Development at MSD</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/tomerwasserman/" id="ember5097" class="ember-view">      <div class="actor-image">
        <div id="ember5098" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQHX6GtgvlKGvA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=AmQCEQXzvdnoNX9PH5BGDe57afVJhWrhw1c6EeGtHsU" class="avatar member EntityPhoto-circle-3" alt="Tomer Wasserman">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Tomer Wasserman
            <span id="ember5099" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Oncology Business Unit Director (AR|UY) at AstraZeneca</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/caroline-le-goff-08b7014a/" id="ember5100" class="ember-view">      <div class="actor-image">
        <div id="ember5101" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQH514_Qd4lJxg/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=CE3izCiZUd-khte8nklLxvN1DQA5yiJljICzD_JYkhA" class="avatar member EntityPhoto-circle-3" alt="Caroline Le Goff">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Caroline Le Goff
            <span id="ember5102" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Global Strategy Lead, GPS Oncology at Roche/Genentech</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/noelia-coto-5846984a/" id="ember5103" class="ember-view">      <div class="actor-image">
        <div id="ember5104" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQEHaW-uBPqcKQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=S2rC_4XPHEc8IAaMxOy7Xbhxy69kppraKkZChmZjrh0" class="avatar member EntityPhoto-circle-3" alt="Noelia Coto">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Noelia Coto
            <span id="ember5105" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Oncology Product Manager en Roche</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/michael-somers-03ba05a/" id="ember5106" class="ember-view">      <div class="actor-image">
        <div id="ember5107" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQFueQq1rYUdNA/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=Uy0uXNFJQcfhiXbrq9RzPP4LXJyvx6IoKaIK8znuFSo" class="avatar member EntityPhoto-circle-3" alt="Michael Somers">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Michael Somers
            <span id="ember5108" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Global Head of Oncology Communications (GPS) at Roche</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/jane-mccoubrey-4029a111/" id="ember5109" class="ember-view">      <div class="actor-image">
        <div id="ember5110" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQFs5N1GM5tfNw/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=UyDANwQZLnjMaN0IGtEd0sOcuu6pOGS0jkvt4yiF8jI" class="avatar member EntityPhoto-circle-3" alt="Jane McCoubrey">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Jane McCoubrey
            <span id="ember5111" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Head GPS Communications at F.Hoffmann-La Roche Ltd</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/manufield/" id="ember5112" class="ember-view">      <div class="actor-image">
        <div id="ember5113" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQFG_tLgDUyiuQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=A-eCCxxZzabO-dJiwD9yiXEQPJrgh3yy-10pgfCDfk8" class="avatar member EntityPhoto-circle-3" alt="Manu Field">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Manu Field
            <span id="ember5114" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">2nd degree connection</span>

<span class="dist-value">2nd</span>
</span>
                  </h3>
        <p class="headline">Passionate about communications that matter and drive business results, and finding new ways to do things better</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/sajid-hansraj-8439a53/" id="ember5115" class="ember-view">      <div class="actor-image">
        <div id="ember5116" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4D03AQGq6WXrkzUwLQ/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=i5qtxCQ7jbW2KZ8XSH_IyrxnRBpShGjVzb-jJAAjZBQ" class="avatar member EntityPhoto-circle-3" alt="Sajid Hansraj">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Sajid Hansraj
            <span id="ember5117" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Director, Commercial Planning at Gilead Sciences</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/salgueiromp/" id="ember5118" class="ember-view">      <div class="actor-image">
        <div id="ember5119" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQFNSox-tRY4Qw/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=rrUFJpSYzgv9woGPmBEVABI1NSA-h5doHUDO4EdS--g" class="avatar member EntityPhoto-circle-3" alt="Pedro Salgueiro, PhD">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Pedro Salgueiro, PhD
            <span id="ember5120" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Medical Affairs / Business Strategy / Personalised Healthcare</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/giselapaulsen/" id="ember5121" class="ember-view">      <div class="actor-image">
        <div id="ember5122" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C5603AQECisdvFLJG4A/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=6YpqQEMNyPnCEIewHvLCVZpA1YIVQawFXe3tR3FHtt0" class="avatar member EntityPhoto-circle-3" alt="Gisela A. Paulsen, MPharm">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Gisela A. Paulsen, MPharm
            <span id="ember5123" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Lifesciences executive w/ passion for agile change management to accelerate clinical trials and ensuring patient access</p>
      </div>
</a>  </li>
  <li class="actor-item">
<a data-control-name="like_actor" href="/in/kathrin-scheidegger-cenni-0088254/" id="ember5124" class="ember-view">      <div class="actor-image">
        <div id="ember5125" class="feed-shared-avatar-image b0 member ember-view">  <img src="https://media.licdn.com/dms/image/C4E03AQF1rIfxrZ_2Hw/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=dxgic8-PE2j1uhhicKvbqMvIOcKhvD8WiAmHB_Swg0o" class="avatar member EntityPhoto-circle-3" alt="Kathrin Scheidegger Cenni">
</div>
      </div>

      <div class="profile-link">
        <h3 class="name">
          Kathrin Scheidegger Cenni
            <span id="ember5126" class="feed-shared-actor-list__distance-badge distance-badge separator ember-view">  <span class="visually-hidden">3rd degree connection</span>

<span class="dist-value">3rd</span>
</span>
                  </h3>
        <p class="headline">Lifecycle Leader Avastin at F. Hoffmann-La Roche AG</p>
      </div>
</a>  </li>

<!----></ul>"""

# %%
soup = BS(text)
soup.find('ul', {"class": "actor-list"})
# Out:
# C:\Users\CRobinson\AppData\Local\Continuum\anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\CRobinson\AppData\Local\Continuum\anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# <ul class="feed-shared-likers-modal__actor-list actor-list ember-view" id="ember4817"> <li class="actor-item">
# <a class="ember-view" data-control-name="like_actor" href="/in/dominic-j-elliston-6bb72b/" id="ember4818"> <div class="actor-image">
# ...

# %%
name = soup.find('h3', {'class': 'name'}).get_text()
job = soup.find('p', {'class': 'headline'}).get_text()

# %%
print(name, job)
# Out:
#           Dominic J. Elliston
#              2nd degree connection
# 2nd
#
#  Managing Director at Galliard Healthcare Communications

# %%
people = soup.find_all('li')
people
# Out:
# [<li class="actor-item">
#  <a class="ember-view" data-control-name="like_actor" href="/in/dominic-j-elliston-6bb72b/" id="ember4818"> <div class="actor-image">
#  <div class="feed-shared-avatar-image b0 member ember-view" id="ember4819"> <img alt="Dominic J. Elliston" class="avatar member EntityPhoto-circle-3" src="https://media.licdn.com/dms/image/C4D03AQGlbxHntfulGg/profile-displayphoto-shrink_100_100/0?e=1550102400&amp;v=beta&amp;t=BTm5qsUJSjmLs9yLOFdUDlEQO1bN0cfmTCj-TFChcD0"/>
#  </div>
#  </div>
#  <div class="profile-link">
#  <h3 class="name">
#            Dominic J. Elliston
#              <span class="feed-shared-actor-list__distance-badge distance-badge separator ember-view" id="ember4820"> <span class="visually-hidden">2nd degree connection</span>
#  <span class="dist-value">2nd</span>
#  </span>
#  </h3>
#  <p class="headline">Managing Director at Galliard Healthcare Communications</p>
#  </div>
#  </a> </li>, <li class="actor-item">
# ...

# %%
l = []
for person in people:
    name = person.find('h3', {'class': 'name'}).get_text().strip()
    job = person.find('p', {'class': 'headline'}).get_text().strip()
    short_link = person.find('a').get('href').strip()
    
    link='www.linkedin.com'+short_link
    post_url=url
    d = {'name': name, 'job':job, 'link':link, 'post_url':post_url}
    l.append(d)

# %%
l
# Out:
# [{'name': 'Dominic J. Elliston\n             2nd degree connection\n2nd',
#   'job': 'Managing Director at Galliard Healthcare Communications',
#   'link': 'www.linkedin.com/in/dominic-j-elliston-6bb72b/',
#   'post_url': 'https://www.linkedin.com/pulse/solids-vs-liquids-could-history-separation-hinder-future-perettie/'},
#  {'name': 'Solange Bishop\n             3rd degree connection\n3rd',
#   'job': 'Clinical Data Analyst at Sarah Cannon Research Institute',
#   'link': 'www.linkedin.com/in/solange-bishop-35b8b255/',
#   'post_url': 'https://www.linkedin.com/pulse/solids-vs-liquids-could-history-separation-hinder-future-perettie/'},
#  {'name': 'Anna Kotzeva\n             3rd degree connection\n3rd',
#   'job': 'Global Pricing & Market Access, Health Technology Assessment at Roche',
#   'link': 'www.linkedin.com/in/anna-kotzeva-113301/',
#   'post_url': 'https://www.linkedin.com/pulse/solids-vs-liquids-could-history-separation-hinder-future-perettie/'},
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(l)

# %%
df.to_excel("linkedin_direct_article_likes_v2.xlsx")
